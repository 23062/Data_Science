# %%
pip install pandas
# Out:
# ...
#
# ...

# %%
import pandas as pd

# %%
file = 'C:\\Users\\Himanshu Chouhan\\Downloads\\services.csv'

# %%
df = pd.read_csv(file)

# %%
df.head()
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
# 3   4            4         NaN               NaN            NaN
# 4   5            5         NaN               NaN            NaN
#
#                            application_process  \
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).
# 3                              Apply by phone.
# 4                       Phone for information.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
# 2  Older adults age 55 or over who can benefit fr...
# 3  Parents, children, families with problems of c...
# ...

# %%
df.head(3)
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
#
#                            application_process  \
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
# 2  Older adults age 55 or over who can benefit fr...
#
#                                          description  \
# 0  A walk-in center for older adults that provide...
# 1  Provides training and job placement to eligibl...
# 2  Offers supportive counseling services to San M...
#
#                                          eligibility email  ...  \
# ...

# %%
df.tail()
# Out:
#     id  location_id  program_id         accepted_payments  \
# 18  19           19         NaN                       NaN
# 19  20           20         NaN                       NaN
# 20  21           21         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                             application_process  \
# 18                    NaN  Call for screening appointment (650-347-3648).
# 19                    NaN                                        Walk in.
# 20                    NaN                 By phone during business hours.
# 21  Fotos para pasaportes               Walk in or apply by phone or mail
# 22                    NaN               Walk in or apply by phone or mail
#
#                                              audience  \
# 18                                                NaN
# 19                                                NaN
# ...

# %%
df[['website']]
# Out:
#                    website
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# 5                      NaN
# 6                      NaN
# 7                      NaN
# 8                      NaN
# 9                      NaN
# 10                     NaN
# 11                     NaN
# 12                     NaN
# 13                     NaN
# 14                     NaN
# 15                     NaN
# 16                     NaN
# 17                     NaN
# 18                     NaN
# 19                     NaN
# 20                     NaN
# 21  http://www.example.com
# 22  http://www.example.com

# %%
df[['email','keywords']]
# Out:
#                     email                                           keywords
# 0                     NaN  ADULT PROTECTION AND CARE SERVICES, Meal Sites...
# 1                     NaN  EMPLOYMENT/TRAINING SERVICES, Job Development,...
# 2                     NaN  Geriatric Counseling, Older Adults, Gay, Lesbi...
# 3                     NaN  INDIVIDUAL AND FAMILY DEVELOPMENT SERVICES, Gr...
# 4                     NaN     COMMUNITY SERVICES, Speakers, Automobile Loans
# 5                     NaN  ADULT PROTECTION AND CARE SERVICES, In-Home Su...
# 6                     NaN  ADULT PROTECTION AND CARE SERVICES, Adult Day ...
# 7                     NaN  ADULT PROTECTION AND CARE SERVICES, Meal Sites...
# 8                     NaN  EDUCATION SERVICES, Library, Libraries, Public...
# 9                     NaN  EDUCATION SERVICES, Library, Libraries, Public...
# 10                    NaN  EDUCATION SERVICES, Library, Libraries, Public...
# ...

# %%
df.dtypes
# Out:
# id                           int64
# location_id                  int64
# program_id                 float64
# accepted_payments           object
# alternate_name              object
# application_process         object
# audience                    object
# description                 object
# eligibility                 object
# email                       object
# fees                        object
# funding_sources             object
# interpretation_services     object
# keywords                    object
# languages                   object
# name                        object
# required_documents          object
# service_areas               object
# status                      object
# wait_time                   object
# website                     object
# taxonomy_ids                object
# dtype: object

# %%
url = 'https://khuyentran1401.github.io/Efficient_Python_tricks_and_tools_for_data_scientists/README.html'

# %%
tables = pd.read_html(url)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 tables = pd.read_html(url)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\html.py:1205, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links)
#    1201 validate_header_arg(header)
#    1203 io = stringify_path(io)
# -> 1205 return _parse(
# ...

# %%
pip install html5lib

# %%
tables = pd.read_html(url)

# %%
tables = pd.read_html(url)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 tables = pd.read_html(url)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\html.py:1205, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links)
#    1201 validate_header_arg(header)
#    1203 io = stringify_path(io)
# -> 1205 return _parse(
# ...

# %%
url1 = 'https://www.census2011.co.in/sexratio.php'

# %%
pd.read_html(url1)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 pd.read_html(url1)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\html.py:1205, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links)
#    1201 validate_header_arg(header)
#    1203 io = stringify_path(io)
# -> 1205 return _parse(
# ...

# %%
pd.read_html('https://www.basketball-refrence.com/leagues/NBA_2015_totals.html')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 pd.read_html('https://www.basketball-refrence.com/leagues/NBA_2015_totals.html')
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\html.py:1205, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links)
#    1201 validate_header_arg(header)
# ...

# %% [markdown]
# # lecture- 2

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df[['Name','Age','Fare','Cabin']]
# Out:
#                                                   Name   Age     Fare Cabin
# 0                              Braund, Mr. Owen Harris  22.0   7.2500   NaN
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  71.2833   C85
# 2                               Heikkinen, Miss. Laina  26.0   7.9250   NaN
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  53.1000  C123
# 4                             Allen, Mr. William Henry  35.0   8.0500   NaN
# ..                                                 ...   ...      ...   ...
# 886                              Montvila, Rev. Juozas  27.0  13.0000   NaN
# 887                       Graham, Miss. Margaret Edith  19.0  30.0000   B42
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN  23.4500   NaN
# 889                              Behr, Mr. Karl Howell  26.0  30.0000  C148
# 890                                Dooley, Mr. Patrick  32.0   7.7500   NaN
#
# [891 rows x 4 columns]

# %%
df.dtypes == 'object'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
df.dtypes [df.dtypes== 'object'].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
df[df.dtypes [df.dtypes== 'object'].index].describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.dtypes [df.dtypes== 'float64']
# Out:
# Age     float64
# Fare    float64
# dtype: object

# %%
df.dtypes[df.dtypes == 'int64']
# Out:
# PassengerId    int64
# Survived       int64
# Pclass         int64
# SibSp          int64
# Parch          int64
# dtype: object

# %%
df[['Ticket']][4:11]
# Out:
#      Ticket
# 4    373450
# 5    330877
# 6     17463
# 7    349909
# 8    347742
# 9    237736
# 10  PP 9549

# %%
df['new_col'] = df['PassengerId'] + df['Pclass']

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pd.Categorical(df['Pclass'])
# Out:
# [3, 1, 3, 1, 3, ..., 2, 1, 3, 1, 3]
# Length: 891
# Categories (3, int64): [1, 2, 3]

# %%
pd.Categorical(df['Ticket'])
# Out:
# ['A/5 21171', 'PC 17599', 'STON/O2. 3101282', '113803', '373450', ..., '211536', '112053', 'W./C. 6607', '111369', '370376']
# Length: 891
# Categories (681, object): ['110152', '110413', '110465', '110564', ..., 'W./C. 6609', 'W.E.P. 5734', 'W/C 14208', 'WE/P 5735']

# %%
df['Cabin'].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
df[df['Age']>18]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df['Fare']>33]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 23            24         1       1
# 27            28         0       1
# ..           ...       ...     ...
# 856          857         1       1
# 863          864         0       3
# 867          868         0       1
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# 27                      Fortune, Mr. Charles Alexander    male  19.0      3
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df['Fare']== 0]
# Out:
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 179          180         0       3               Leonard, Mr. Lionel  male
# 263          264         0       1             Harrison, Mr. William  male
# 271          272         1       3      Tornquist, Mr. William Henry  male
# 277          278         0       2       Parkes, Mr. Francis "Frank"  male
# 302          303         0       3   Johnson, Mr. William Cahoone Jr  male
# 413          414         0       2    Cunningham, Mr. Alfred Fleming  male
# 466          467         0       2             Campbell, Mr. William  male
# 481          482         0       2  Frost, Mr. Anthony Wood "Archie"  male
# 597          598         0       3               Johnson, Mr. Alfred  male
# 633          634         0       1     Parr, Mr. William Henry Marsh  male
# 674          675         0       2        Watson, Mr. Ennis Hastings  male
# ...

# %%
df[df['Sex'] == 'male']
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked  new_col
# ...

# %%
df[df['Sex'] == 'female']
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df['Survived'] == 1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df['Survived'] == 0]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 6              7         0       1                   McCarthy, Mr. Timothy J
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
df[(df['Sex'] == 'female')&(df['Fare'] >32.204208)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 31            32         1       1
# 43            44         1       2
# 52            53         1       1
# ..           ...       ...     ...
# 853          854         1       1
# 856          857         1       1
# 863          864         0       3
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 43            Laroche, Miss. Simonne Marie Anne Andree  female   3.0      1
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
max(df['Fare'])
# Out:
# 512.3292

# %%
df[df['Fare']==512.3292]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked  \
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
#
#      new_col
# 258      260
# 679      681
# 737      739

# %%
df[df['Fare']==512.3292]['Name']
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
df[145:321]
# Out:
#      PassengerId  Survived  Pclass  \
# 145          146         0       2
# 146          147         1       3
# 147          148         0       3
# 148          149         0       2
# 149          150         0       2
# ..           ...       ...     ...
# 316          317         1       2
# 317          318         0       2
# 318          319         1       1
# 319          320         1       1
# 320          321         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 145                       Nicholls, Mr. Joseph Charles    male  19.0      1
# 146       Andersson, Mr. August Edvard ("Wennerstrom")    male  27.0      0
# 147                   Ford, Miss. Robina Maggie "Ruby"  female   9.0      2
# 148           Navratil, Mr. Michel ("Louis M Hoffman")    male  36.5      0
# 149                  Byles, Rev. Thomas Roussel Davids    male  42.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[['PassengerId','Survived','Pclass']][0:2]
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3
# 1            2         1       1

# %% [markdown]
# # lecture 3

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.drop('PassengerId')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df.drop('PassengerId')
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.drop('PassengerId',axis=1)
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.drop(3)
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 4           0       3                           Allen, Mr. William Henry
# 5           0       3                                   Moran, Mr. James
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.drop(3, inplace=True)

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 4           0       3                           Allen, Mr. William Henry
# 5           0       3                                   Moran, Mr. James
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.set_index('Name')
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Allen, Mr. William Henry                                   0       3    male
# Moran, Mr. James                                           0       3    male
# ...                                                      ...     ...     ...
# Montvila, Rev. Juozas                                      0       2    male
# Graham, Miss. Margaret Edith                               1       1  female
# Johnston, Miss. Catherine Helen "Carrie"                   0       3  female
# Behr, Mr. Karl Howell                                      1       1    male
# Dooley, Mr. Patrick                                        0       3    male
#
# ...

# %%
df.reset_index()
# Out:
#      index  Survived  Pclass  \
# 0        0         0       3
# 1        1         1       1
# 2        2         1       3
# 3        4         0       3
# 4        5         0       3
# ..     ...       ...     ...
# 885    886         0       2
# 886    887         1       1
# 887    888         0       3
# 888    889         1       1
# 889    890         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3                             Allen, Mr. William Henry    male  35.0      0
# 4                                     Moran, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 4           0       3                           Allen, Mr. William Henry
# 5           0       3                                   Moran, Mr. James
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
d = { 'key1' : [1,2,3,4,5],
     'key2' : [6,7,8,9,10],
     'key3' : [11,12,13,14,15]
    
}

# %% [markdown]
# converting dictionary to data frame

# %%
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     1     6    11
# 1     2     7    12
# 2     3     8    13
# 3     4     9    14
# 4     5    10    15

# %%
df1 = pd.read_csv('C:\\Users\\Himanshu Chouhan\\Downloads\\taxonomy.csv.xls')

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %% [markdown]
# dropna : this will drop all the Nan data from the table .
# inplace = True : this will make chaange permanent

# %%
df1.dropna(inplace =True)

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 5     101-02-03          Help Pay for Housing    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [279 rows x 4 columns]

# %%
df2 = pd.read_csv("C:\\Users\\Himanshu Chouhan\\Downloads\\taxonomy.csv.xls")

# %% [markdown]
# fillna : this will fill the value with the user given value

# %%
df2.fillna("himu")
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency      himu                  himu
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df.reset_index(inplace = True)

# %%
df
# Out:
#      index  Survived  Pclass  \
# 0        0         0       3
# 1        1         1       1
# 2        2         1       3
# 3        4         0       3
# 4        5         0       3
# ..     ...       ...     ...
# 885    886         0       2
# 886    887         1       1
# 887    888         0       3
# 888    889         1       1
# 889    890         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3                             Allen, Mr. William Henry    male  35.0      0
# 4                                     Moran, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
g = df.groupby('Survived')

# %%
g

# %%
g.sum()
# Out:
# C:\Users\Himanshu Chouhan\AppData\Local\Temp\ipykernel_11960\1197020669.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.sum()
#            index  Pclass       Age  SibSp  Parch        Fare
# Survived
# 0         244863    1390  12985.50    304    181  12142.7199
# 1         151629     666   8184.67    161    159  16498.1294

# %%
g.mean()
# Out:
# C:\Users\Himanshu Chouhan\AppData\Local\Temp\ipykernel_11960\2978112660.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.mean()
#                index    Pclass        Age     SibSp     Parch       Fare
# Survived
# 0         446.016393  2.531876  30.626179  0.553734  0.329690  22.117887
# 1         444.659824  1.953079  28.320657  0.472141  0.466276  48.381611

# %%
g.max()
# Out:
# C:\Users\Himanshu Chouhan\AppData\Local\Temp\ipykernel_11960\557829741.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   g.max()
#           index  Pclass                         Name   Sex   Age  SibSp  \
# Survived
# 0           890       3  van Melkebeke, Mr. Philemon  male  74.0      8
# 1           889       3      de Mulder, Mr. Theodore  male  80.0      4
#
#           Parch     Ticket      Fare
# Survived
# 0             6  WE/P 5735  263.0000
# 1             5  WE/P 5735  512.3292

# %%
g1 = df.groupby('Pclass')

# %%
g1.mean()
# Out:
# C:\Users\Himanshu Chouhan\AppData\Local\Temp\ipykernel_11960\3287460031.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g1.mean()
#              index  Survived        Age     SibSp     Parch       Fare
# Pclass
# 1       462.725581  0.627907  38.250919  0.413953  0.358140  84.299128
# 2       444.956522  0.472826  29.877630  0.402174  0.380435  20.662183
# 3       438.154786  0.242363  25.140620  0.615071  0.393075  13.675550

# %%
g1.tail()
# Out:
#      index  Survived  Pclass  \
# 865    866         1       2
# 870    871         1       1
# 871    872         0       1
# 873    874         1       2
# 878    879         1       1
# 879    880         1       2
# 881    882         0       3
# 882    883         0       2
# 883    884         0       3
# 884    885         0       3
# 885    886         0       2
# 886    887         1       1
# 887    888         0       3
# 888    889         1       1
# 889    890         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 865                      Duran y More, Miss. Asuncion  female  27.0      1
# 870  Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 871                          Carlsson, Mr. Frans Olof    male  33.0      0
# 873             Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.0      1
# 878     Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# ...

# %%
g1.sum()
# Out:
# C:\Users\Himanshu Chouhan\AppData\Local\Temp\ipykernel_11960\2725926089.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g1.sum()
#          index  Survived      Age  SibSp  Parch        Fare
# Pclass
# 1        99486       135  7076.42     89     77  18124.3125
# 2        81872        87  5168.83     74     70   3801.8417
# 3       215134       119  8924.92    302    193   6714.6951

# %%
g1.max()
# Out:
# C:\Users\Himanshu Chouhan\AppData\Local\Temp\ipykernel_11960\130714741.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   g1.max()
#         index  Survived                         Name   Sex   Age  SibSp  \
# Pclass
# 1         889         1     Young, Miss. Marie Grice  male  80.0      3
# 2         886         1    del Carlo, Mr. Sebastiano  male  70.0      3
# 3         890         1  van Melkebeke, Mr. Philemon  male  74.0      8
#
#         Parch      Ticket      Fare
# Pclass
# 1           4   WE/P 5735  512.3292
# 2           3   W/C 14208   73.5000
# 3           6  W./C. 6609   69.5500

# %%
g1.max()['Fare']
# Out:
# C:\Users\Himanshu Chouhan\AppData\Local\Temp\ipykernel_11960\730728694.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   g1.max()['Fare']
# Pclass
# 1    512.3292
# 2     73.5000
# 3     69.5500
# Name: Fare, dtype: float64

# %%
g1.mean()['Fare']
# Out:
# C:\Users\Himanshu Chouhan\AppData\Local\Temp\ipykernel_11960\216811123.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g1.mean()['Fare']
# Pclass
# 1    84.299128
# 2    20.662183
# 3    13.675550
# Name: Fare, dtype: float64

# %%
g1.max().transpose()
# Out:
# C:\Users\Himanshu Chouhan\AppData\Local\Temp\ipykernel_11960\3907411846.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   g1.max().transpose()
# Pclass                           1                          2  \
# index                          889                        886
# Survived                         1                          1
# Name      Young, Miss. Marie Grice  del Carlo, Mr. Sebastiano
# Sex                           male                       male
# Age                           80.0                       70.0
# SibSp                            3                          3
# Parch                            4                          3
# Ticket                   WE/P 5735                  W/C 14208
# Fare                      512.3292                       73.5
#
# Pclass                              3
# ...

# %%
df5 = df[['Name', 'Survived','Pclass' ]][0:5]

# %%
df6 = df[['Name','Survived','Pclass']][5:10]

# %%
df5
# Out:
#                                                 Name  Survived  Pclass
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3                           Allen, Mr. William Henry         0       3
# 4                                   Moran, Mr. James         0       3

# %%
df6
# Out:
#                                                 Name  Survived  Pclass
# 5                            McCarthy, Mr. Timothy J         0       1
# 6                     Palsson, Master. Gosta Leonard         0       3
# 7  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1       3
# 8                Nasser, Mrs. Nicholas (Adele Achem)         1       2
# 9                    Sandstrom, Miss. Marguerite Rut         1       3

# %%
pd.concat([df5,df6])
# Out:
#                                                 Name  Survived  Pclass
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3                           Allen, Mr. William Henry         0       3
# 4                                   Moran, Mr. James         0       3
# 5                            McCarthy, Mr. Timothy J         0       1
# 6                     Palsson, Master. Gosta Leonard         0       3
# 7  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1       3
# 8                Nasser, Mrs. Nicholas (Adele Achem)         1       2
# 9                    Sandstrom, Miss. Marguerite Rut         1       3

# %%
df7 = pd.concat([df5,df6],axis=1)

# %%
df7.fillna("himu")
# Out:
#                                                 Name Survived Pclass  \
# 0                            Braund, Mr. Owen Harris      0.0    3.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1.0    1.0
# 2                             Heikkinen, Miss. Laina      1.0    3.0
# 3                           Allen, Mr. William Henry      0.0    3.0
# 4                                   Moran, Mr. James      0.0    3.0
# 5                                               himu     himu   himu
# 6                                               himu     himu   himu
# 7                                               himu     himu   himu
# 8                                               himu     himu   himu
# 9                                               himu     himu   himu
#
#                                                 Name Survived Pclass
# 0                                               himu     himu   himu
# 1                                               himu     himu   himu
# ...

# %%
data1 = pd.DataFrame({'key1':[1,2,3,4,5],
                      'key2':[6,7,8,9,10],
                      'key3':[11,12,13,14,15]
                     
                     })

# %%
data2 = pd.DataFrame({'key1':[23,24,25,26,27],
                      'key4':[33,34,35,36,37],
                      'key5':[1,2,3,4,5]
                     
                     })

# %%
data2
# Out:
#    key1  key4  key5
# 0    23    33     1
# 1    24    34     2
# 2    25    35     3
# 3    26    36     4
# 4    27    37     5

# %%
pd.merge(data1,data2)
# Out:
# Empty DataFrame
# Columns: [key1, key2, key3, key4, key5]
# Index: []

# %%
data1 = pd.DataFrame({'key1':[1,2,4,5,6],
                      'key2':[4,5,6,7,8],
                      'key3':[3,4,5,6,6]},
                      index = ['a','b','c','d','e']
                     
                     )

# %%
data2 = pd.DataFrame({'key11':[1,2,4,5,6],
                      'key42':[4,5,6,7,8],
                      'key53':[3,4,5,6,6]},
                      index = ['a','b','h','i','k']
                     
                     )

# %%
data1
# Out:
#    key1  key2  key3
# a     1     4     3
# b     2     5     4
# c     4     6     5
# d     5     7     6
# e     6     8     6

# %%
data2
# Out:
#    key11  key42  key53
# a      1      4      3
# b      2      5      4
# h      4      6      5
# i      5      7      6
# k      6      8      6

# %%
data1.join(data2)
# Out:
#    key1  key2  key3  key11  key42  key53
# a     1     4     3    1.0    4.0    3.0
# b     2     5     4    2.0    5.0    4.0
# c     4     6     5    NaN    NaN    NaN
# d     5     7     6    NaN    NaN    NaN
# e     6     8     6    NaN    NaN    NaN

# %%
df
# Out:
#      index  Survived  Pclass  \
# 0        0         0       3
# 1        1         1       1
# 2        2         1       3
# 3        4         0       3
# 4        5         0       3
# ..     ...       ...     ...
# 885    886         0       2
# 886    887         1       1
# 887    888         0       3
# 888    889         1       1
# 889    890         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3                             Allen, Mr. William Henry    male  35.0      0
# 4                                     Moran, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Fare_INR'] = df['Fare'].apply(lambda x : x*80)

# %%
df
# Out:
#      index  Survived  Pclass  \
# 0        0         0       3
# 1        1         1       1
# 2        2         1       3
# 3        4         0       3
# 4        5         0       3
# ..     ...       ...     ...
# 885    886         0       2
# 886    887         1       1
# 887    888         0       3
# 888    889         1       1
# 889    890         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3                             Allen, Mr. William Henry    male  35.0      0
# 4                                     Moran, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
def euro_to_inr(x):
    return x*80

df['INR'] = df['Fare'].apply(euro_to_inr)

# %%
df
# Out:
#      index  Survived  Pclass  \
# 0        0         0       3
# 1        1         1       1
# 2        2         1       3
# 3        4         0       3
# 4        5         0       3
# ..     ...       ...     ...
# 885    886         0       2
# 886    887         1       1
# 887    888         0       3
# 888    889         1       1
# 889    890         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3                             Allen, Mr. William Henry    male  35.0      0
# 4                                     Moran, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['name_len'] = df['Name'].apply(len)

# %%
df.head()
# Out:
#    index  Survived  Pclass                                               Name  \
# 0      0         0       3                            Braund, Mr. Owen Harris
# 1      1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2      2         1       3                             Heikkinen, Miss. Laina
# 3      4         0       3                           Allen, Mr. William Henry
# 4      5         0       3                                   Moran, Mr. James
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3    male  35.0      0      0            373450   8.0500   NaN        S
# 4    male   NaN      0      0            330877   8.4583   NaN        Q
#
#    Fare_INR       INR  name_len
# ...

# %%
def cat_fare(x):
    if x<10:
        return "Cheap"
    elif x>=10 and x<20:
        return "mid"
    else:
        return "high"
df['cheapOne'] = df['Fare'].apply(cat_fare)

# %%
df.head()
# Out:
#    index  Survived  Pclass                                               Name  \
# 0      0         0       3                            Braund, Mr. Owen Harris
# 1      1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2      2         1       3                             Heikkinen, Miss. Laina
# 3      4         0       3                           Allen, Mr. William Henry
# 4      5         0       3                                   Moran, Mr. James
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3    male  35.0      0      0            373450   8.0500   NaN        S
# 4    male   NaN      0      0            330877   8.4583   NaN        Q
#
#    Fare_INR       INR  name_len cheapOne
# ...

# %% [markdown]
# # lecture

# %%
import pandas as pd

# %%
data = {
    'a':[1,2,3,4,5],
    'b':[4,5,6,7,8],
    'c':["himu",'rocky','deep','ravi','raju']
}

# %%
dff = pd.DataFrame(data)

# %%
dff.set_index('a',inplace = True)

# %%
dff
# Out:
#    b      c
# a
# 1  4   himu
# 2  5  rocky
# 3  6   deep
# 4  7   ravi
# 5  8   raju

# %%
dff.reset_index()
# Out:
#    a  b      c
# 0  1  4   himu
# 1  2  5  rocky
# 2  3  6   deep
# 3  4  7   ravi
# 4  5  8   raju

# %%
data = {
    'a':[1,2,3,4,5],
    'b':[4,5,6,7,8],
    'c':["himu",'rocky','deep','ravi','raju']
}
dff1 = pd.DataFrame(data, index = ['a','b','c','d','e'])

# %%
dff1
# Out:
#    a  b      c
# a  1  4   himu
# b  2  5  rocky
# c  3  6   deep
# d  4  7   ravi
# e  5  8   raju

# %%
dff1.reindex(['c','d','a','b','e'])
# Out:
#    a  b      c
# c  3  6   deep
# d  4  7   ravi
# a  1  4   himu
# b  2  5  rocky
# e  5  8   raju

# %%
dff1
# Out:
#    a  b      c
# a  1  4   himu
# b  2  5  rocky
# c  3  6   deep
# d  4  7   ravi
# e  5  8   raju

# %%
def test(x):
    return x.sum()
    
dff1.apply(test)
# Out:
# a                       15
# b                       30
# c    himurockydeepraviraju
# dtype: object

# %%
dff2 = dff1[['a','b']]

# %%
dff2
# Out:
#    a  b
# a  1  4
# b  2  5
# c  3  6
# d  4  7
# e  5  8

# %%
dff2.apply(lambda x : x**2)
# Out:
#     a   b
# a   1  16
# b   4  25
# c   9  36
# d  16  49
# e  25  64

# %%
dff1.sort_values('c')
# Out:
#    a  b      c
# c  3  6   deep
# a  1  4   himu
# e  5  8   raju
# d  4  7   ravi
# b  2  5  rocky

# %%
dff1.sort_index(ascending = False)
# Out:
#    a  b      c
# e  5  8   raju
# d  4  7   ravi
# c  3  6   deep
# b  2  5  rocky
# a  1  4   himu

# %%
pd.set_option('display.max_colwidth',800)
dff3 = pd.DataFrame({'Disc':['Making Education Interesting For School StudentsThe idea of beginning with the school section came up when the government made online learning compulsory for schools. Around 90% of parents are worried about whether their child would learn everything through this online learning”. No worries, our esteemed faculty at Adda247 left no stone unturned in making the concept clear to the students in the most fun and interesting manner. As students prefer mobile for games, cartoons, and movies, and in this scenario, making learning Fun and Engaging For Children is the toughest task for any teacher and our faculty at Adda247 is a PRO in this field.','my name is himanshu','my friend name is rocky']})

# %%
dff3
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Disc
# ...

# %%
dff3[len] = dff3['Disc'].apply(len)

# %%
dff3
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Disc  \
# ...

# %%
dff3['word'] = dff3['Disc'].apply(lambda x : len(x.split()))

# %%
dff3
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Disc  \
# ...

# %%
dff1['a'].mean()
# Out:
# 3.0

# %%
dff2['b'].mode()
# Out:
# 0    4
# 1    5
# 2    6
# 3    7
# 4    8
# Name: b, dtype: int64

# %%
dff2['a'].median()
# Out:
# 3.0

# %%
dff2['a'].std()
# Out:
# 1.5811388300841898

# %%
dff2['a'].sum()
# Out:
# 15

# %%
dff2['a'].max()
# Out:
# 5

# %%
dff2['a'].view()
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# Name: a, dtype: int64

# %%
dff4 = pd.DataFrame({'a':[1,2,3,2,4,3,56,34,6,4,]})

# %%
dff4
# Out:
#     a
# 0   1
# 1   2
# 2   3
# 3   2
# 4   4
# 5   3
# 6  56
# 7  34
# 8   6
# 9   4

# %%
dff4['a'].rolling(window=1).mean()
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     2.0
# 4     4.0
# 5     3.0
# 6    56.0
# 7    34.0
# 8     6.0
# 9     4.0
# Name: a, dtype: float64

# %%
dff4['a'].rolling(window=2).mean()
# Out:
# 0     NaN
# 1     1.5
# 2     2.5
# 3     2.5
# 4     3.0
# 5     3.5
# 6    29.5
# 7    45.0
# 8    20.0
# 9     5.0
# Name: a, dtype: float64

# %%
dff4['a'].rolling(window=3).mean()
# Out:
# 0          NaN
# 1          NaN
# 2     2.000000
# 3     2.333333
# 4     3.000000
# 5     3.000000
# 6    21.000000
# 7    31.000000
# 8    32.000000
# 9    14.666667
# Name: a, dtype: float64

# %%
date = pd.date_range(start='2023-04-23', end='2023-05-23')

# %%
date
# Out:
# DatetimeIndex(['2023-04-23', '2023-04-24', '2023-04-25', '2023-04-26',
#                '2023-04-27', '2023-04-28', '2023-04-29', '2023-04-30',
#                '2023-05-01', '2023-05-02', '2023-05-03', '2023-05-04',
#                '2023-05-05', '2023-05-06', '2023-05-07', '2023-05-08',
#                '2023-05-09', '2023-05-10', '2023-05-11', '2023-05-12',
#                '2023-05-13', '2023-05-14', '2023-05-15', '2023-05-16',
#                '2023-05-17', '2023-05-18', '2023-05-19', '2023-05-20',
#                '2023-05-21', '2023-05-22', '2023-05-23'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.DataFrame({'date':date})
# Out:
#          date
# 0  2023-04-23
# 1  2023-04-24
# 2  2023-04-25
# 3  2023-04-26
# 4  2023-04-27
# 5  2023-04-28
# 6  2023-04-29
# 7  2023-04-30
# 8  2023-05-01
# 9  2023-05-02
# 10 2023-05-03
# 11 2023-05-04
# 12 2023-05-05
# 13 2023-05-06
# 14 2023-05-07
# 15 2023-05-08
# 16 2023-05-09
# 17 2023-05-10
# 18 2023-05-11
# 19 2023-05-12
# 20 2023-05-13
# 21 2023-05-14
# 22 2023-05-15
# 23 2023-05-16
# 24 2023-05-17
# 25 2023-05-18
# 26 2023-05-19
# 27 2023-05-20
# 28 2023-05-21
# 29 2023-05-22
# 30 2023-05-23
